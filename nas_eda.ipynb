# %%
#Import Libs
import pandas as pd
import numpy as np

# For ordered categorical data
from pandas.api.types import CategoricalDtype

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read the data
df_nas = pd.read_csv("../nas_2014.csv")

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### 1. Check the range of the marks

# %%
df_nas.filter(like='%', axis=1).describe()
# Out:
#             Maths %     Reading %     Science %      Social %
# count  92469.000000  93175.000000  90956.000000  89528.000000
# mean      32.259371     46.223004     36.416349     38.361449
# std       16.089177     21.829832     14.906687     15.132517
# min        0.000000      0.000000      0.000000      0.000000
# 25%       21.670000     27.590000     25.930000     28.000000
# 50%       27.780000     43.330000     33.930000     36.000000
# 75%       37.930000     63.330000     44.640000     48.000000
# max      100.000000    100.000000    100.000000     96.000000

# %% [markdown]
# The average for Reading is maximum and Maths is minimum.

# %% [markdown]
# ##### 1.1 How many students have 100 in maths

# %%
print (f"There are {df_nas[df_nas['Maths %'] == 100].shape[0]} students with 100% marks in Maths.")
# Out:
# There are 9 students with 100% marks in Maths.

# %% [markdown]
# ##### 1.2 How many students have 100 in Reading

# %%
df_nas[df_nas['Reading %'] == 100].shape[0]
# Out:
# 81

# %% [markdown]
# #### 2 By State
# ##### 2.1 Top 5 states with highest and lowest number of students

# %%
df_nas['State'].value_counts().head(5)
# Out:
# Maharashtra       8785
# Kerala            8742
# Tamil Nadu        8218
# Gujarat           7889
# Andhra Pradesh    7763
# Name: State, dtype: int64

# %%
df_nas['State'].value_counts().tail(5)
# Out:
# Sikkim                  3577
# Andaman & Nicobar       2510
# Dadra & Nagar Haveli    2390
# Nagaland                1919
# Daman & Diu              483
# Name: State, dtype: int64

# %% [markdown]
# ##### 2.2 Top 5 states with highest Total % and lowest Total %

# %%
df_state = df_nas.groupby('State')['Maths %','Science %','Social %','Reading %'].mean()
df_state['Total %'] = df_state[['Maths %', 'Reading %', 'Science %', 'Social %']].mean(axis=1)

# %%
# Top 5 State - by  sort 
df_state.sort_values('Total %',ascending=False).head(5)
# Out:
#                         Maths %  Science %   Social %  Reading %    Total %
# State
# Daman & Diu           39.070363  48.567978  48.445183  58.417366  48.625223
# Uttar Pradesh         46.249564  40.087269  47.424712  46.053547  44.953773
# Dadra & Nagar Haveli  39.190759  45.362350  43.819593  46.789067  43.790442
# Tripura               39.786913  43.287356  43.204400  43.883633  42.540576
# Kerala                28.968597  38.932014  42.944913  58.496412  42.335484

# %%
# Bottom 5 State - by  sort 
df_state.sort_values('Total %',ascending=True).head(5)
# Out:
#                     Maths %  Science %   Social %  Reading %    Total %
# State
# Pondicherry       26.010226  30.576886  30.387150  40.093955  31.767054
# Meghalaya         27.458645  32.435003  32.502283  39.642971  33.009725
# Tamil Nadu        27.449596  31.780568  31.405126  43.151505  33.446698
# Andhra Pradesh    28.661412  32.675898  33.765278  43.151303  34.563473
# Himachal Pradesh  28.120950  32.825157  35.014599  44.994749  35.238864

# %% [markdown]
# #### 3 Check the difference in marks By Gender

# %%
df_gen = df_nas.groupby('Gender')['Maths %','Science %','Social %','Reading %'].mean()
df_gen['Total %'] = df_gen[['Maths %', 'Reading %', 'Science %', 'Social %']].mean(axis=1)
df_gen
# Out:
#           Maths %  Science %   Social %  Reading %   Total %
# Gender
# Boy     32.169603  36.369447  38.094746  45.225684  37.96487
# Girl    32.330895  36.459287  38.616089  47.162410  38.64217

# %%
# Get the difference in marks by gender 

df_gen2 = df_gen.T
df_gen2['Marks Diff'] = df_gen2['Girl'] - df_gen2['Boy']
df_gen2 = df_gen2.T
df_gen2
# Out:
#               Maths %  Science %   Social %  Reading %   Total %
# Gender
# Boy         32.169603  36.369447  38.094746  45.225684  37.96487
# Girl        32.330895  36.459287  38.616089  47.162410  38.64217
# Marks Diff   0.161291   0.089840   0.521343   1.936726   0.67730

# %% [markdown]
# On an average, Girls score more  than boys

# %%
### Function to calculate the avearge marks by the factor and the difference between the factors

def nas_groupby_diff(df,groupby_col,diff1,diff2,markDiffFlag):
    df_t = df.groupby(groupby_col)['Maths %','Science %','Social %','Reading %'].mean()
    df_t['Total %'] = df_t[['Maths %', 'Reading %', 'Science %', 'Social %']].mean(axis=1)
    
    if markDiffFlag == 'Yes' :
        # Convert the cols to str type - from ordered cat - so as to insert a new column
        df_t.index = df_t.index.astype(str)

        # Transpose and get the diff
        df_t = df_t.T
        df_t['Marks Diff'] = df_t[diff1] - df_t[diff2]

        # Transpose it back
        df_t = df_t.T

    return df_t

# %% [markdown]
# #### 4 Get the difference in marks By Parents Education

# %%
df_nas['Father edu'].value_counts(dropna=False)
# Out:
# Primary           58588
# Illiterate        45881
# Secondary         44034
# Not applicable    16784
# Sr secondary      12856
# Degree & above     6866
# Name: Father edu, dtype: int64

# %%
# Filter 'Not Applicable'
df_nas = df_nas[df_nas['Father edu'] != 'Not applicable']
df_nas = df_nas[df_nas['Mother edu'] != 'Not applicable']

# %%
# Convert to orderd category
ordered_level = ['Illiterate', 'Primary', 'Secondary', 'Sr secondary','Degree & above']
ord_cat_type = CategoricalDtype(categories=ordered_level, ordered=True)
df_nas['Father edu'] = df_nas['Father edu'].astype(ord_cat_type)
df_nas['Mother edu'] = df_nas['Mother edu'].astype(ord_cat_type)

# %%
df_t = nas_groupby_diff(df_nas,'Father edu','Degree & above','Illiterate','No')
df_t.style.highlight_min(axis=0,color='hotpink').highlight_max(axis=0,color='greenyellow')
# Out:
# <style  type="text/css" >
#     #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col0 {
#             background-color:  hotpink;
#             : ;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col1 {
#             background-color:  hotpink;
#             : ;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col2 {
#             background-color:  hotpink;
#             : ;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col3 {
#             background-color:  hotpink;
#             : ;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col4 {
#             background-color:  hotpink;
#             : ;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col0 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col1 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col2 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col3 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col4 {
#             : ;
#             background-color:  greenyellow;
#         }</style><table id="T_1960f5ee_9bce_11e9_95b0_780cb8323cef" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maths %</th>        <th class="col_heading level0 col1" >Science %</th>        <th class="col_heading level0 col2" >Social %</th>        <th class="col_heading level0 col3" >Reading %</th>        <th class="col_heading level0 col4" >Total %</th>    </tr>    <tr>        <th class="index_name level0" >Father edu</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1960f5ee_9bce_11e9_95b0_780cb8323ceflevel0_row0" class="row_heading level0 row0" >Illiterate</th>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col0" class="data row0 col0" >31.4088</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col1" class="data row0 col1" >34.3795</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col2" class="data row0 col2" >36.8</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col3" class="data row0 col3" >41.1787</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow0_col4" class="data row0 col4" >35.9417</td>
#             </tr>
#             <tr>
#                         <th id="T_1960f5ee_9bce_11e9_95b0_780cb8323ceflevel0_row1" class="row_heading level0 row1" >Primary</th>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow1_col0" class="data row1 col0" >32.3516</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow1_col1" class="data row1 col1" >36.3996</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow1_col2" class="data row1 col2" >38.2791</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow1_col3" class="data row1 col3" >46.1875</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow1_col4" class="data row1 col4" >38.3045</td>
#             </tr>
#             <tr>
#                         <th id="T_1960f5ee_9bce_11e9_95b0_780cb8323ceflevel0_row2" class="row_heading level0 row2" >Secondary</th>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow2_col0" class="data row2 col0" >32.3771</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow2_col1" class="data row2 col1" >37.3067</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow2_col2" class="data row2 col2" >39.3235</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow2_col3" class="data row2 col3" >49.141</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow2_col4" class="data row2 col4" >39.537</td>
#             </tr>
#             <tr>
#                         <th id="T_1960f5ee_9bce_11e9_95b0_780cb8323ceflevel0_row3" class="row_heading level0 row3" >Sr secondary</th>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow3_col0" class="data row3 col0" >33.777</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow3_col1" class="data row3 col1" >38.7012</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow3_col2" class="data row3 col2" >40.9368</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow3_col3" class="data row3 col3" >53.3786</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow3_col4" class="data row3 col4" >41.6984</td>
#             </tr>
#             <tr>
#                         <th id="T_1960f5ee_9bce_11e9_95b0_780cb8323ceflevel0_row4" class="row_heading level0 row4" >Degree & above</th>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col0" class="data row4 col0" >37.8377</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col1" class="data row4 col1" >44.2371</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col2" class="data row4 col2" >44.6042</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col3" class="data row4 col3" >59.8803</td>
#                         <td id="T_1960f5ee_9bce_11e9_95b0_780cb8323cefrow4_col4" class="data row4 col4" >46.6398</td>
#             </tr>
#     </tbody></table>

# %%
nas_groupby_diff(df_nas,'Father edu','Degree & above','Illiterate','Yes')
# Out:
#                   Maths %  Science %   Social %  Reading %    Total %
# Father edu
# Illiterate      31.408764  34.379484  36.799957  41.178664  35.941717
# Primary         32.351572  36.399630  38.279091  46.187523  38.304454
# Secondary       32.377078  37.306677  39.323480  49.140951  39.537047
# Sr secondary    33.777039  38.701228  40.936847  53.378605  41.698430
# Degree & above  37.837705  44.237098  44.604247  59.880302  46.639838
# Marks Diff       6.428942   9.857614   7.804290  18.701638  10.698121

# %%
nas_groupby_diff(df_nas,'Mother edu','Degree & above','Illiterate','Yes')
# Out:
#                   Maths %  Science %   Social %  Reading %    Total %
# Mother edu
# Illiterate      32.249772  35.317110  37.660295  42.760053  36.996808
# Primary         32.357862  36.331347  38.295381  46.552162  38.384188
# Secondary       32.120475  37.607013  39.560079  50.947038  40.058651
# Sr secondary    34.336969  40.524849  41.926885  56.420657  43.302340
# Degree & above  36.590882  45.799305  45.478484  61.430497  47.324792
# Marks Diff       4.341111  10.482195   7.818189  18.670444  10.327985

# %% [markdown]
# Observe a difference in ~18% in Reading and ~10% between Illetrate and 'Degree and Above', for both Mother and Father's education level

# %% [markdown]
# ##### 4.1 Get the number of students by Educatin level and Gender

# %%
df_nas.pivot_table(index='Gender', columns='Father edu', values='STUID',aggfunc='count')
# Out:
# Father edu  Illiterate  Primary  Secondary  Sr secondary  Degree & above
# Gender
# Boy              20319    25554      18584          5396            2796
# Girl             18975    27644      21592          6591            3528

# %%
df_nas.pivot_table(index='Gender', columns='Father edu', values='STUID',aggfunc='count')
# Out:
# Father edu  Illiterate  Primary  Secondary  Sr secondary  Degree & above
# Gender
# Boy              20319    25554      18584          5396            2796
# Girl             18975    27644      21592          6591            3528

# %% [markdown]
# #### 5 How does the factor 'Play Games' affects the marks

# %%
df_nas['Play games'].value_counts(dropna=False)
# Out:
# Every day       94715
# Once a week     30250
# Never           12057
# Once a month    12007
# NaN              2115
# Name: Play games, dtype: int64

# %%
ordered_level = ['Never', 'Once a month', 'Once a week', 'Every day']
ord_cat_type = CategoricalDtype(categories=ordered_level, ordered=True)
df_nas['Play games'] = df_nas['Play games'].astype(ord_cat_type)

df_t = nas_groupby_diff(df_nas,'Play games','Never','Every day','No')
df_t.style.highlight_min(axis=0,color='violet').highlight_max(axis=0,color='turquoise')
# Out:
# <style  type="text/css" >
#     #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col0 {
#             background-color:  violet;
#             : ;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col1 {
#             background-color:  violet;
#             : ;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col2 {
#             background-color:  violet;
#             : ;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col3 {
#             background-color:  violet;
#             : ;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col4 {
#             background-color:  violet;
#             : ;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow1_col3 {
#             : ;
#             background-color:  turquoise;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col0 {
#             : ;
#             background-color:  turquoise;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col1 {
#             : ;
#             background-color:  turquoise;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col2 {
#             : ;
#             background-color:  turquoise;
#         }    #T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col4 {
#             : ;
#             background-color:  turquoise;
#         }</style><table id="T_19f25b6e_9bce_11e9_af3e_780cb8323cef" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maths %</th>        <th class="col_heading level0 col1" >Science %</th>        <th class="col_heading level0 col2" >Social %</th>        <th class="col_heading level0 col3" >Reading %</th>        <th class="col_heading level0 col4" >Total %</th>    </tr>    <tr>        <th class="index_name level0" >Play games</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_19f25b6e_9bce_11e9_af3e_780cb8323ceflevel0_row0" class="row_heading level0 row0" >Never</th>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col0" class="data row0 col0" >29.9518</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col1" class="data row0 col1" >33.0958</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col2" class="data row0 col2" >36.3266</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col3" class="data row0 col3" >43.7339</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow0_col4" class="data row0 col4" >35.777</td>
#             </tr>
#             <tr>
#                         <th id="T_19f25b6e_9bce_11e9_af3e_780cb8323ceflevel0_row1" class="row_heading level0 row1" >Once a month</th>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow1_col0" class="data row1 col0" >31.4908</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow1_col1" class="data row1 col1" >35.8206</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow1_col2" class="data row1 col2" >38.6801</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow1_col3" class="data row1 col3" >48.5623</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow1_col4" class="data row1 col4" >38.6385</td>
#             </tr>
#             <tr>
#                         <th id="T_19f25b6e_9bce_11e9_af3e_780cb8323ceflevel0_row2" class="row_heading level0 row2" >Once a week</th>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow2_col0" class="data row2 col0" >32.2932</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow2_col1" class="data row2 col1" >36.9829</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow2_col2" class="data row2 col2" >38.7255</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow2_col3" class="data row2 col3" >47.9523</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow2_col4" class="data row2 col4" >38.9885</td>
#             </tr>
#             <tr>
#                         <th id="T_19f25b6e_9bce_11e9_af3e_780cb8323ceflevel0_row3" class="row_heading level0 row3" >Every day</th>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col0" class="data row3 col0" >33.036</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col1" class="data row3 col1" >37.1543</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col2" class="data row3 col2" >39.0377</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col3" class="data row3 col3" >46.8829</td>
#                         <td id="T_19f25b6e_9bce_11e9_af3e_780cb8323cefrow3_col4" class="data row3 col4" >39.0277</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Playing everyday increases the marks !

# %%
# Get the difference
nas_groupby_diff(df_nas,'Play games','Every day','Never','Yes')
# Out:
#                 Maths %  Science %   Social %  Reading %    Total %
# Play games
# Never         29.951786  33.095756  36.326595  43.733896  35.777008
# Once a month  31.490789  35.820615  38.680128  48.562293  38.638456
# Once a week   32.293202  36.982858  38.725550  47.952296  38.988476
# Every day     33.035967  37.154341  39.037714  46.882871  39.027723
# Marks Diff     3.084181   4.058586   2.711119   3.148975   3.250715

# %% [markdown]
# #### 6 Get the effect of all factors with  difference in the minimum and maximum marks per factor

# %%
# Read the data
df_nas_factor = pd.read_csv("../nas_byFactor_2014.csv")

# %%
cm = sns.light_palette("blue", as_cmap=True)

df_nas_factor.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow0_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow0_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow0_col4 {
#             background-color:  #e1e1ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow0_col5 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow1_col1 {
#             background-color:  #9696ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow1_col2 {
#             background-color:  #9595ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow1_col3 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow1_col4 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow1_col5 {
#             background-color:  #8d8dff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow2_col1 {
#             background-color:  #d3d3ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow2_col2 {
#             background-color:  #c6c6ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow2_col3 {
#             background-color:  #c2c2ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow2_col4 {
#             background-color:  #d8d8ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow2_col5 {
#             background-color:  #b1b1ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow3_col1 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow3_col2 {
#             background-color:  #a6a6ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow3_col3 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow3_col4 {
#             background-color:  #9797ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow3_col5 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow4_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow4_col2 {
#             background-color:  #2929ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow4_col3 {
#             background-color:  #0a0aff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow4_col4 {
#             background-color:  #1111ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow4_col5 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow5_col1 {
#             background-color:  #0808ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow5_col2 {
#             background-color:  #6363ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow5_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow5_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow5_col5 {
#             background-color:  #0505ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow6_col1 {
#             background-color:  #0707ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow6_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow6_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow6_col4 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow6_col5 {
#             background-color:  #1212ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow7_col1 {
#             background-color:  #3131ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow7_col2 {
#             background-color:  #4f4fff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow7_col3 {
#             background-color:  #4444ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow7_col4 {
#             background-color:  #0f0fff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow7_col5 {
#             background-color:  #3434ff;
#             color:  #f1f1f1;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow8_col1 {
#             background-color:  #aaaaff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow8_col2 {
#             background-color:  #9e9eff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow8_col3 {
#             background-color:  #afafff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow8_col4 {
#             background-color:  #9191ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow8_col5 {
#             background-color:  #ababff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow9_col1 {
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow9_col2 {
#             background-color:  #d1d1ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow9_col3 {
#             background-color:  #ababff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow9_col4 {
#             background-color:  #b5b5ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow9_col5 {
#             background-color:  #b4b4ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow10_col1 {
#             background-color:  #d1d1ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow10_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow10_col3 {
#             background-color:  #b9b9ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow10_col4 {
#             background-color:  #d8d8ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow10_col5 {
#             background-color:  #c6c6ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow11_col1 {
#             background-color:  #acacff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow11_col2 {
#             background-color:  #c8c8ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow11_col3 {
#             background-color:  #a3a3ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow11_col4 {
#             background-color:  #b2b2ff;
#             color:  #000000;
#         }    #T_1a1d4500_9bce_11e9_a007_780cb8323cefrow11_col5 {
#             background-color:  #a2a2ff;
#             color:  #0

# %%
# Make Factor as the index column
df_nas_factor.set_index('Factor', inplace=True)

# %%
### Get the factors having the largets effect on the Total %
df_nas_factor.sort_values('Total %',ascending=False).head(5)
# Out:
#                      Total %   Maths %  Science %  Social %  Reading %
# Factor
# Father edu         10.804898  7.147734   9.878618  7.858566  18.842922
# Father occupation  10.459215  8.721214  10.344859  8.474012  17.400177
# Mother edu         10.420815  5.003750  10.327734  8.444972  18.377394
# Mother occupation   8.665225  5.743442   7.286746  7.921499  14.853603
# Help in household   5.154852  4.641360   4.984875  6.489467   5.674657

# %%
### Get the factors having the least effect on the Total %
df_nas_factor.sort_values('Total %',ascending=True).head(5)
# Out:
#                   Total %   Maths %  Science %  Social %  Reading %
# Factor
# Gender           0.677300  0.161291   0.089840  0.521343   1.936726
# Distance         0.767315  2.171856   0.894036  0.878486   1.238056
# Private tuition  1.229088  1.268174   1.168420  0.330589   2.149170
# Siblings         1.489900  1.317671   1.687458  0.830884   5.233149
# Use Internet     1.610506  0.138483   2.064682  0.816788   3.699035

# %%
### Get the factors having the largets effect on the Maths %
df_nas_factor.sort_values('Maths %',ascending=False).head(5)
# Out:
#                      Total %   Maths %  Science %  Social %  Reading %
# Factor
# Father occupation  10.459215  8.721214  10.344859  8.474012  17.400177
# Father edu         10.804898  7.147734   9.878618  7.858566  18.842922
# Computer use        3.338935  6.501020   3.174619  4.056019   5.861707
# Mother occupation   8.665225  5.743442   7.286746  7.921499  14.853603
# Mother edu         10.420815  5.003750  10.327734  8.444972  18.377394

# %%
### Get the factors having the largets effect on the Science %
df_nas_factor.sort_values('Science %',ascending=False).head(5)
# Out:
#                      Total %   Maths %  Science %  Social %  Reading %
# Factor
# Father occupation  10.459215  8.721214  10.344859  8.474012  17.400177
# Mother edu         10.420815  5.003750  10.327734  8.444972  18.377394
# Father edu         10.804898  7.147734   9.878618  7.858566  18.842922
# Mother occupation   8.665225  5.743442   7.286746  7.921499  14.853603
# Help in household   5.154852  4.641360   4.984875  6.489467   5.674657

# %%
### Get the factors having the largets effect on the Social %
df_nas_factor.nlargest(5,'Social %').index.values
# Out:
# array(['Father occupation', 'Mother edu', 'Mother occupation',
#        'Father edu', 'Help in household'], dtype=object)

# %% [markdown]
# #### 7 Check the effect of Parents Education and Gender on marks

# %%
### Function to calculate the groupby marks average
def nas_2_groupby_marks(df,groupby_col1,groupby_col2):
    df_t = df.groupby([groupby_col1,groupby_col2])['Maths %','Science %','Social %','Reading %'].mean()
    df_t['Total %'] = df_t[['Maths %', 'Reading %', 'Science %', 'Social %']].mean(axis=1)
    
    return df_t

# %%
df_t = nas_2_groupby_marks(df_nas,'Mother edu','Gender')
df_t.style.highlight_min(axis=0,color='lightcoral').highlight_max(axis=0,color='lime')
# Out:
# <style  type="text/css" >
#     #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow0_col3 {
#             background-color:  lightcoral;
#             : ;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col1 {
#             background-color:  lightcoral;
#             : ;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col2 {
#             background-color:  lightcoral;
#             : ;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col4 {
#             background-color:  lightcoral;
#             : ;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow4_col0 {
#             background-color:  lightcoral;
#             : ;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow9_col0 {
#             : ;
#             background-color:  lime;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow9_col1 {
#             : ;
#             background-color:  lime;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow9_col2 {
#             : ;
#             background-color:  lime;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow9_col3 {
#             : ;
#             background-color:  lime;
#         }    #T_1acda6a4_9bce_11e9_b062_780cb8323cefrow9_col4 {
#             : ;
#             background-color:  lime;
#         }</style><table id="T_1acda6a4_9bce_11e9_b062_780cb8323cef" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maths %</th>        <th class="col_heading level0 col1" >Science %</th>        <th class="col_heading level0 col2" >Social %</th>        <th class="col_heading level0 col3" >Reading %</th>        <th class="col_heading level0 col4" >Total %</th>    </tr>    <tr>        <th class="index_name level0" >Mother edu</th>        <th class="index_name level1" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel0_row0" class="row_heading level0 row0" rowspan=2>Illiterate</th>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row0" class="row_heading level1 row0" >Boy</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow0_col0" class="data row0 col0" >32.1767</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow0_col1" class="data row0 col1" >35.5569</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow0_col2" class="data row0 col2" >37.82</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow0_col3" class="data row0 col3" >42.7291</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow0_col4" class="data row0 col4" >37.0707</td>
#             </tr>
#             <tr>
#                                 <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row1" class="row_heading level1 row1" >Girl</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col0" class="data row1 col0" >32.2935</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col1" class="data row1 col1" >35.0565</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col2" class="data row1 col2" >37.5048</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col3" class="data row1 col3" >42.8119</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow1_col4" class="data row1 col4" >36.9167</td>
#             </tr>
#             <tr>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel0_row2" class="row_heading level0 row2" rowspan=2>Primary</th>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row2" class="row_heading level1 row2" >Boy</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow2_col0" class="data row2 col0" >32.3862</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow2_col1" class="data row2 col1" >36.3695</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow2_col2" class="data row2 col2" >37.9705</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow2_col3" class="data row2 col3" >45.5848</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow2_col4" class="data row2 col4" >38.0778</td>
#             </tr>
#             <tr>
#                                 <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row3" class="row_heading level1 row3" >Girl</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow3_col0" class="data row3 col0" >32.319</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow3_col1" class="data row3 col1" >36.2983</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow3_col2" class="data row3 col2" >38.5884</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow3_col3" class="data row3 col3" >47.4369</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow3_col4" class="data row3 col4" >38.6606</td>
#             </tr>
#             <tr>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel0_row4" class="row_heading level0 row4" rowspan=2>Secondary</th>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row4" class="row_heading level1 row4" >Boy</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow4_col0" class="data row4 col0" >32.0964</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow4_col1" class="data row4 col1" >37.2656</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow4_col2" class="data row4 col2" >38.8374</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow4_col3" class="data row4 col3" >49.1771</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow4_col4" class="data row4 col4" >39.3441</td>
#             </tr>
#             <tr>
#                                 <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row5" class="row_heading level1 row5" >Girl</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow5_col0" class="data row5 col0" >32.1447</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow5_col1" class="data row5 col1" >37.8954</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow5_col2" class="data row5 col2" >40.1786</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow5_col3" class="data row5 col3" >52.4522</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow5_col4" class="data row5 col4" >40.6677</td>
#             </tr>
#             <tr>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel0_row6" class="row_heading level0 row6" rowspan=2>Sr secondary</th>
#                         <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row6" class="row_heading level1 row6" >Boy</th>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow6_col0" class="data row6 col0" >33.686</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow6_col1" class="data row6 col1" >40.0768</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow6_col2" class="data row6 col2" >41.0214</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow6_col3" class="data row6 col3" >53.4701</td>
#                         <td id="T_1acda6a4_9bce_11e9_b062_780cb8323cefrow6_col4" class="data row6 col4" >42.0636</td>
#             </tr>
#             <tr>
#                                 <th id="T_1acda6a4_9bce_11e9_b062_780cb8323ceflevel1_row7" class="row_heading level1 row7" >Girl</th>
#                         <td id="T_1acda6a4

# %%
df_t = nas_2_groupby_marks(df_nas,'Father edu','Gender')
df_t.style.highlight_min(axis=0,color='violet').highlight_max(axis=0,color='springgreen')
# Out:
# <style  type="text/css" >
#     #T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col0 {
#             background-color:  violet;
#             : ;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col2 {
#             background-color:  violet;
#             : ;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col3 {
#             background-color:  violet;
#             : ;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col4 {
#             background-color:  violet;
#             : ;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow1_col1 {
#             background-color:  violet;
#             : ;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow9_col0 {
#             : ;
#             background-color:  springgreen;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow9_col1 {
#             : ;
#             background-color:  springgreen;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow9_col2 {
#             : ;
#             background-color:  springgreen;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow9_col3 {
#             : ;
#             background-color:  springgreen;
#         }    #T_1b021746_9bce_11e9_9541_780cb8323cefrow9_col4 {
#             : ;
#             background-color:  springgreen;
#         }</style><table id="T_1b021746_9bce_11e9_9541_780cb8323cef" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maths %</th>        <th class="col_heading level0 col1" >Science %</th>        <th class="col_heading level0 col2" >Social %</th>        <th class="col_heading level0 col3" >Reading %</th>        <th class="col_heading level0 col4" >Total %</th>    </tr>    <tr>        <th class="index_name level0" >Father edu</th>        <th class="index_name level1" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel0_row0" class="row_heading level0 row0" rowspan=2>Illiterate</th>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row0" class="row_heading level1 row0" >Boy</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col0" class="data row0 col0" >31.2846</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col1" class="data row0 col1" >34.461</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col2" class="data row0 col2" >36.8002</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col3" class="data row0 col3" >40.9506</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow0_col4" class="data row0 col4" >35.8741</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row1" class="row_heading level1 row1" >Girl</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow1_col0" class="data row1 col0" >31.5384</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow1_col1" class="data row1 col1" >34.2967</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow1_col2" class="data row1 col2" >36.8098</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow1_col3" class="data row1 col3" >41.4503</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow1_col4" class="data row1 col4" >36.0238</td>
#             </tr>
#             <tr>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel0_row2" class="row_heading level0 row2" rowspan=2>Primary</th>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row2" class="row_heading level1 row2" >Boy</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow2_col0" class="data row2 col0" >32.3357</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow2_col1" class="data row2 col1" >36.6408</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow2_col2" class="data row2 col2" >38.2085</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow2_col3" class="data row2 col3" >45.5242</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow2_col4" class="data row2 col4" >38.1773</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row3" class="row_heading level1 row3" >Girl</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow3_col0" class="data row3 col0" >32.3237</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow3_col1" class="data row3 col1" >36.1598</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow3_col2" class="data row3 col2" >38.3496</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow3_col3" class="data row3 col3" >46.794</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow3_col4" class="data row3 col4" >38.4068</td>
#             </tr>
#             <tr>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel0_row4" class="row_heading level0 row4" rowspan=2>Secondary</th>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row4" class="row_heading level1 row4" >Boy</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow4_col0" class="data row4 col0" >32.4362</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow4_col1" class="data row4 col1" >36.9912</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow4_col2" class="data row4 col2" >38.8304</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow4_col3" class="data row4 col3" >47.6968</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow4_col4" class="data row4 col4" >38.9886</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row5" class="row_heading level1 row5" >Girl</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow5_col0" class="data row5 col0" >32.3251</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow5_col1" class="data row5 col1" >37.5767</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow5_col2" class="data row5 col2" >39.7513</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow5_col3" class="data row5 col3" >50.4086</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow5_col4" class="data row5 col4" >40.0154</td>
#             </tr>
#             <tr>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel0_row6" class="row_heading level0 row6" rowspan=2>Sr secondary</th>
#                         <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row6" class="row_heading level1 row6" >Boy</th>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow6_col0" class="data row6 col0" >33.6962</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow6_col1" class="data row6 col1" >38.772</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow6_col2" class="data row6 col2" >40.3974</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow6_col3" class="data row6 col3" >51.5833</td>
#                         <td id="T_1b021746_9bce_11e9_9541_780cb8323cefrow6_col4" class="data row6 col4" >41.1122</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b021746_9bce_11e9_9541_780cb8323ceflevel1_row7" class="row_heading level1 row7" >Girl</th>
#                         <t

# %% [markdown]
# #### 8 What is the difference in  marks by the factors Play Games and Read other books

# %%
df_t = nas_2_groupby_marks(df_nas,'Play games','Read other books')
df_t.style.highlight_min(axis=0,color='pink').highlight_max(axis=0,color='greenyellow')
# Out:
# <style  type="text/css" >
#     #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col0 {
#             background-color:  pink;
#             : ;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col1 {
#             background-color:  pink;
#             : ;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col2 {
#             background-color:  pink;
#             : ;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col4 {
#             background-color:  pink;
#             : ;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow3_col3 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow6_col3 {
#             background-color:  pink;
#             : ;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow7_col0 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow7_col1 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow7_col2 {
#             : ;
#             background-color:  greenyellow;
#         }    #T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow7_col4 {
#             : ;
#             background-color:  greenyellow;
#         }</style><table id="T_1b2f6118_9bce_11e9_b9de_780cb8323cef" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maths %</th>        <th class="col_heading level0 col1" >Science %</th>        <th class="col_heading level0 col2" >Social %</th>        <th class="col_heading level0 col3" >Reading %</th>        <th class="col_heading level0 col4" >Total %</th>    </tr>    <tr>        <th class="index_name level0" >Play games</th>        <th class="index_name level1" >Read other books</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel0_row0" class="row_heading level0 row0" rowspan=2>Never</th>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row0" class="row_heading level1 row0" >No</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col0" class="data row0 col0" >30.2674</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col1" class="data row0 col1" >32.1738</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col2" class="data row0 col2" >35.4719</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col3" class="data row0 col3" >42.2736</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow0_col4" class="data row0 col4" >35.0467</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row1" class="row_heading level1 row1" >Yes</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow1_col0" class="data row1 col0" >30.3159</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow1_col1" class="data row1 col1" >33.9725</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow1_col2" class="data row1 col2" >37.2481</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow1_col3" class="data row1 col3" >45.4952</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow1_col4" class="data row1 col4" >36.7579</td>
#             </tr>
#             <tr>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel0_row2" class="row_heading level0 row2" rowspan=2>Once a month</th>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row2" class="row_heading level1 row2" >No</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow2_col0" class="data row2 col0" >30.4018</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow2_col1" class="data row2 col1" >33.588</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow2_col2" class="data row2 col2" >37.2038</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow2_col3" class="data row2 col3" >43.3051</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow2_col4" class="data row2 col4" >36.1247</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row3" class="row_heading level1 row3" >Yes</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow3_col0" class="data row3 col0" >32.0878</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow3_col1" class="data row3 col1" >36.9058</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow3_col2" class="data row3 col2" >39.5344</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow3_col3" class="data row3 col3" >50.9101</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow3_col4" class="data row3 col4" >39.8595</td>
#             </tr>
#             <tr>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel0_row4" class="row_heading level0 row4" rowspan=2>Once a week</th>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row4" class="row_heading level1 row4" >No</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow4_col0" class="data row4 col0" >31.3168</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow4_col1" class="data row4 col1" >34.9654</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow4_col2" class="data row4 col2" >36.5619</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow4_col3" class="data row4 col3" >43.2745</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow4_col4" class="data row4 col4" >36.5296</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row5" class="row_heading level1 row5" >Yes</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow5_col0" class="data row5 col0" >32.8827</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow5_col1" class="data row5 col1" >37.8553</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow5_col2" class="data row5 col2" >39.5296</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow5_col3" class="data row5 col3" >49.9049</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow5_col4" class="data row5 col4" >40.0431</td>
#             </tr>
#             <tr>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel0_row6" class="row_heading level0 row6" rowspan=2>Every day</th>
#                         <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row6" class="row_heading level1 row6" >No</th>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow6_col0" class="data row6 col0" >32.8966</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow6_col1" class="data row6 col1" >35.5168</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow6_col2" class="data row6 col2" >37.2836</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow6_col3" class="data row6 col3" >41.9829</td>
#                         <td id="T_1b2f6118_9bce_11e9_b9de_780cb8323cefrow6_col4" class="data row6 col4" >36.92</td>
#             </tr>
#             <tr>
#                                 <th id="T_1b2f6118_9bce_11e9_b9de_780cb8323ceflevel1_row7" class="row_heading level1 row7" >Yes</th>
#                         <td id="T_1

# %% [markdown]
# #### 9 Which Subject do students score most/least

# %%
df_nas_marks = df_nas.filter(like='%').copy()

# %%
# Get the max marks columns
df_nas_marks['highest_marks'] = df_nas_marks.idxmax(axis='columns')
# Get the min marks columns
df_nas_marks['lowest_marks'] = df_nas_marks.drop('highest_marks', axis='columns').idxmin(axis='columns')

# %%
df_nas_marks['highest_marks'].value_counts(normalize=True)
# Out:
# Reading %    0.369876
# Social %     0.263707
# Science %    0.221958
# Maths %      0.144458
# Name: highest_marks, dtype: float64

# %%
df_nas_marks['lowest_marks'].value_counts(normalize=True)
# Out:
# Maths %      0.369198
# Science %    0.270389
# Social %     0.213560
# Reading %    0.146853
# Name: lowest_marks, dtype: float64

# %% [markdown]
# ##### 9.1 For students with highest score in Maths what is the 2nd highest scoring subject

# %%
pd.crosstab(df_nas_marks['highest_marks'],df_nas_marks['lowest_marks'],normalize=1)
# Out:
# lowest_marks    Maths %  Reading %  Science %  Social %
# highest_marks
# Maths %        0.058561   0.648681   0.066312  0.045172
# Reading %      0.770093   0.126807   0.111624  0.172109
# Science %      0.096229   0.093916   0.076774  0.711182
# Social %       0.075117   0.130595   0.745289  0.071537

# %%
#If highest in Maths then  what is the 2nd highest 
(df_nas_marks[df_nas_marks['highest_marks'] == 'Maths %']
 .drop(['Maths %','highest_marks','lowest_marks'], axis='columns')
 .idxmax(axis='columns')
 .value_counts(normalize=True)
)
# Out:
# Reading %    0.775662
# Science %    0.145012
# Social %     0.079326
# dtype: float64

# %%
#If highest in Reading then  what is the 2nd highest 
(df_nas_marks[df_nas_marks['highest_marks'] == 'Reading %']
 .drop(['Reading %','highest_marks','lowest_marks'], axis='columns')
 .idxmax(axis='columns')
 .value_counts(normalize=True)
)
# Out:
# Maths %      0.770806
# Social %     0.131546
# Science %    0.097648
# dtype: float64

# %%
#If highest in Science then  what is the 2nd highest 
(df_nas_marks[df_nas_marks['highest_marks'] == 'Science %']
 .drop(['Science %','highest_marks','lowest_marks'], axis='columns')
 .idxmax(axis='columns')
 .value_counts(normalize=True)
)
# Out:
# Social %     0.762414
# Maths %      0.164072
# Reading %    0.073514
# dtype: float64

# %%
#If highest in Social then  what is the 2nd highest 
(df_nas_marks[df_nas_marks['highest_marks'] == 'Social %']
 .drop(['Social %','highest_marks','lowest_marks'], axis='columns')
 .idxmax(axis='columns')
 .value_counts(normalize=True)
)
# Out:
# Science %    0.815347
# Maths %      0.103823
# Reading %    0.080830
# dtype: float64

# %% [markdown]
# Observe some affinity for marks between Social and Science and between Maths and Reading
#
# ##### 9.2 Check the correlation

# %%
df_nas.filter(like='%').corr()
# Out:
#             Maths %  Reading %  Science %  Social %
# Maths %    1.000000   0.349076   0.504585  0.521961
# Reading %  0.349076   1.000000   0.432412  0.463202
# Science %  0.504585   0.432412   1.000000  0.560325
# Social %   0.521961   0.463202   0.560325  1.000000

# %%
#If lowest is Maths, what is the highest 
(df_nas_marks[df_nas_marks['lowest_marks'] == 'Maths %']
 .drop(['Maths %','highest_marks','lowest_marks'], axis='columns')
 .idxmax(axis='columns')
 .value_counts(normalize=True)
)
# Out:
# Reading %    0.819173
# Science %    0.101615
# Social %     0.079212
# dtype: float64

# %%
#If lowest is Maths, what is next lowest
(df_nas_marks[df_nas_marks['lowest_marks'] == 'Maths %']
 .drop(['Maths %','highest_marks','lowest_marks'], axis='columns')
 .idxmin(axis='columns')
 .value_counts(normalize=True)
)
# Out:
# Reading %    0.77838
# Science %    0.12535
# Social %     0.09627
# dtype: float64

# %% [markdown]
# #### 10 Interactive , calculate for all cobination of Factors

# %%
import ipywidgets as widgets
from ipywidgets import interact_manual

# %% [markdown]
# ##### 10.1 Interactive , Single Factor

# %%
@interact_manual
def nas_grpby_interactive(col=list(df_nas.drop('State',axis=1).select_dtypes(include=[object]).columns.values)):
    
    # Remove nan
    df = df_nas.dropna(subset = [col])
    df_t = nas_groupby_diff(df,col,'ignore','ignore','No')                      
    #print(df_t.style.highlight_min(axis=0).apply(highlight_max))
    print(df_t)
# Out:
# interactive(children=(Dropdown(description='col', options=('Use computer', 'Gender', 'Age', 'Siblings', 'Handi…

# %% [markdown]
# ##### 10.2 Interactive , by two factors

# %%
@interact_manual
def nas_grpby_interactive(col1=list(df_nas.drop('State',axis=1).select_dtypes(include=[object]).columns.values), 
                          col2=list(df_nas.drop('State',axis=1).select_dtypes(include=[object]).columns.values)[1:]) :
    
    # Remove nan
    df = df_nas.dropna(subset = [col1, col2])
    df_t = nas_2_groupby_marks(df,col1,col2)                      
    #print(df_t.style.highlight_min(axis=0).apply(highlight_max))
    print(df_t)
# Out:
# interactive(children=(Dropdown(description='col1', options=('Use computer', 'Gender', 'Age', 'Siblings', 'Hand…
